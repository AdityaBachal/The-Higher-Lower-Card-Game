# %%
import time, os, random

ranks = ["Ace","2","3","4","5","6","7","8","9","10","Jack","Queen","King"]
suits = ["Clubs","Hearts","Diamonds","Spades"]
deck = []

value = 1
for rank in ranks:
    for suit in suits:
        deck.append([rank + " of " + suit, value])
    value = value + 1

random.shuffle(deck)
score = 0
card1 = deck.pop(0)

while True:
    os.system("cls")
    print("Your score so far is", score)
    print("\n\nThe current card is", card1[0])
    while True:
        choice = input("Bet on next card whether it will be higher or lower?   ")
        if len(choice) > 0:
            if choice[0].lower() in ["h","l"]:
                break
        

    card2 = deck.pop(0)
    print("The next card picked is", card2[0])
    time.sleep(1)

    if choice[0].lower() == "h" and card2[1] > card1[1]:
        print("Correct!")
        score +=1
        time.sleep(1)
        card1 = card2
        continue
    if choice[0].lower() == "h" and card2[1] < card1[1]:
        print("Wrong!")
        time.sleep(1)
        break
    if choice[0].lower() == "l" and card2[1] < card1[1]:
        print("Correct!")
        score +=1
        time.sleep(1)
        card1 = card2
        continue
    if choice[0].lower() == "l" and card2[1] > card1[1]:
        print("Wrong!")
        time.sleep(1)
        break
    else:
        print("draw!")

    card1 = card2

os.system("cls")
print("Game over!")
print("You final score is", score)
time.sleep(2)
os.system("cls")
# Out:
# Your score so far is 0
#
#
# The current card is 10 of Diamonds
# Bet on next card whether it will be higher or lower?   l
# The next card picked is 9 of Clubs
# Correct!
# Your score so far is 1
#
#
# The current card is 9 of Clubs
# Bet on next card whether it will be higher or lower?   h
# The next card picked is King of Clubs
# Correct!
# Your score so far is 2
#
#
# The current card is King of Clubs
# Bet on next card whether it will be higher or lower?   l
# The next card picked is 7 of Diamonds
# Correct!
# Your score so far is 3
#
#
# The current card is 7 of Diamonds
# Bet on next card whether it will be higher or lower?   h
# The next card picked is 8 of Hearts
# Correct!
# Your score so far is 4
#
#
# The current card is 8 of Hearts
# Bet on next card whether it will be higher or lower?   l
# The next card picked is Ace of Diamonds
# Correct!
# Your score so far is 5
#
#
# The current card is Ace of Diamonds
# Bet on next card whether it will be higher or lower?   h
# The next card picked is Queen of Hearts
# Correct!
# Your score so far is 6
#
#
# The current card is Queen of Hearts
# Bet on next card whether it will be higher or lower?   l
# The next card picked is 9 of Hearts
# Correct!
# Your score so far is 7
#
#
# The current card is 9 of Hearts
# Bet on next card whether it will be higher or lower?   h
# The next card picked is Queen of Spades
# Correct!
# Your score so far is 8
#
#
# The current card is Queen of Spades
# Bet on next card whether it will be higher or lower?   l
# The next card picked is Jack of Hearts
# Correct!
# Your score so far is 9
#
#
# The current card is Jack of Hearts
# Bet on next card whether it will be higher or lower?   h
# The next card picked is 9 of Spades
# Wrong!
# Game over!
# You final score is 9
# 0
